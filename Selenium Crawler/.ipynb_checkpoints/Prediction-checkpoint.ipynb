# %%
import pandas as pd
import pickle
filename = 'finalized_model.sav'
clf = pickle.load(open(filename, 'rb'))

# %%
clf
# Out:
# RandomForestClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=4,
#                        n_estimators=400, random_state=42)

# %%
data = pd.read_csv("today.csv")
data["B365H"] = data["HomeDecimal"].astype("float")
data["B365D"] = data["DrawDecimal"].astype("float")
data["B365A"] = data["AwayDecimal"].astype("float")
data
# Out:
#                      HomeTeam                AwayTeam  Home  Draw  Away  \
# 0                 England U19               Italy U19  -118   250   275
# 1                Slovakia U19             Austria U19   190   240   120
# 2                  France U19              Israel U19  -350   425   700
# 3            Atlético Tucumán              Godoy Cruz   187   210   160
# 4          Ferro Carril Oeste       CA Chaco For Ever   120   162   333
# 5               Nueva Chicago               CA Guemes   125   187   280
# 6      Defensores de Belgrano       Chacarita Juniors   145   180   250
# 7        Universidad de Chile       General Velásquez  -700   550  2500
# 8            Shandong Taishan  Henan Songshan Longmen   100   250   260
# 9              Guangzhou City              Dalian Pro   275   260  -106
# 10          Sportivo Ameliano             Guairena FC  -300   350   800
# 11                    Tacuary          Sol de America   240   210   125
# 12  CD Universidad San Martin     Deportivo Municipal   300   140   150
# 13                   Halmstad          Trelleborgs FF  -167   280   375
# 14           Jonkopings Sodra              Orgryte IS   137   275   160
# 15                  Norrby IF           Ostersunds FK  -225   320   500
# 16       Montevideo Wanderers                  Torque   150   210   170
#
#     HomeDecimal  DrawDecimal  AwayDecimal
# 0      1.847458         3.50     3.750000
# 1      2.900000         3.40     2.200000
# 2      1.285714         5.25     8.000000
# 3      2.870000         3.10     2.600000
# 4      2.200000         2.62     4.330000
# 5      2.250000         2.87     3.800000
# 6      2.450000         2.80     3.500000
# 7      1.142857         6.50    26.000000
# 8      2.000000         3.50     3.600000
# 9      3.750000         3.60     1.943396
# 10     1.333333         4.50     9.000000
# 11     3.400000         3.10     2.250000
# 12     4.000000         2.40     2.500000
# 13     1.598802         3.80     4.750000
# 14     2.370000         3.75     2.600000
# 15     1.444444         4.20     6.000000
# 16     2.500000         3.10     2.700000

# %%
import numpy as np
predictProba =[]
Proba = []
df = data[["B365H","B365D","B365A"]]
for el in clf.predict_proba(df):
  choose = max(el)
  indexChoice = list(el).index(choose)

  if indexChoice == 0:
    predictProba.append("A")
  if indexChoice == 1:
    predictProba.append("D")
  if indexChoice == 2:
    predictProba.append("H")
  
  Proba.append(choose)
# Out:
# c:\users\khoas\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - AwayDecimal
# - DrawDecimal
# - HomeDecimal
# Feature names seen at fit time, yet now missing:
# - WHA
# - WHD
# - WHH
#
#   warnings.warn(message, FutureWarning)

# %%
data["bet"] = predictProba
data["Proba"] = Proba
data
# Out:
#                      HomeTeam                AwayTeam  Home  Draw  Away  \
# 0                 England U19               Italy U19  -118   250   275
# 1                Slovakia U19             Austria U19   190   240   120
# 2                  France U19              Israel U19  -350   425   700
# 3            Atlético Tucumán              Godoy Cruz   187   210   160
# 4          Ferro Carril Oeste       CA Chaco For Ever   120   162   333
# 5               Nueva Chicago               CA Guemes   125   187   280
# 6      Defensores de Belgrano       Chacarita Juniors   145   180   250
# 7        Universidad de Chile       General Velásquez  -700   550  2500
# 8            Shandong Taishan  Henan Songshan Longmen   100   250   260
# 9              Guangzhou City              Dalian Pro   275   260  -106
# 10          Sportivo Ameliano             Guairena FC  -300   350   800
# 11                    Tacuary          Sol de America   240   210   125
# 12  CD Universidad San Martin     Deportivo Municipal   300   140   150
# 13                   Halmstad          Trelleborgs FF  -167   280   375
# 14           Jonkopings Sodra              Orgryte IS   137   275   160
# 15                  Norrby IF           Ostersunds FK  -225   320   500
# 16       Montevideo Wanderers                  Torque   150   210   170
#
#     HomeDecimal  DrawDecimal  AwayDecimal bet     Proba
# 0      1.847458         3.50     3.750000   H  0.507530
# 1      2.900000         3.40     2.200000   A  0.394958
# 2      1.285714         5.25     8.000000   H  0.774760
# 3      2.870000         3.10     2.600000   A  0.365317
# 4      2.200000         2.62     4.330000   H  0.465815
# 5      2.250000         2.87     3.800000   H  0.473509
# 6      2.450000         2.80     3.500000   H  0.491893
# 7      1.142857         6.50    26.000000   H  0.758061
# 8      2.000000         3.50     3.600000   H  0.437495
# 9      3.750000         3.60     1.943396   A  0.529200
# 10     1.333333         4.50     9.000000   H  0.726228
# 11     3.400000         3.10     2.250000   A  0.395790
# 12     4.000000         2.40     2.500000   A  0.604087
# 13     1.598802         3.80     4.750000   H  0.710504
# 14     2.370000         3.75     2.600000   A  0.412845
# 15     1.444444         4.20     6.000000   H  0.736052
# 16     2.500000         3.10     2.700000   H  0.355303
